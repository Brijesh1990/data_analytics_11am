# %%
name="brijeshkumar pandey"
age=34
department="IT"
print(name)
print(age)
print(department)
# Out:
# brijeshkumar pandey
# 34
# IT

# %%
name="brijesh kumar pandey"
age=34
department="IT"
print("my name is :",name)
print("my age is :",age)
print("i am woring in :",department)
# Out:
# my name is : brijesh kumar pandey
# my age is : 34
# i am woring in : IT
